# %%
import pandas as pd

# %%
percapitaGDP = pd.read_excel("GDPpercapita.xlsx",
   sheet_name="OECD.Stat export",
   skiprows=4,
   skipfooter=1,
   usecols="A,C:T")
percapitaGDP.head()
# Out:
#                          Year   2001   2002   2003   2004   2005   2006  \
# 0          Metropolitan areas    NaN    NaN    NaN    NaN    NaN    NaN
# 1              AUS: Australia     ..     ..     ..     ..     ..     ..
# 2       AUS01: Greater Sydney  43313  44008  45424  45837  45423  45547
# 3    AUS02: Greater Melbourne  40125  40894  41602  42188  41484  41589
# 4     AUS03: Greater Brisbane  37580  37564  39080  40762  42976  44475
#
#     2007   2008   2009   2010   2011   2012   2013   2014   2015   2016  \
# 0    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1     ..     ..     ..     ..     ..     ..     ..     ..     ..     ..
# 2  45880  45225  45900  45672  46535  47350  47225  48510  50075  50519
# 3  42316  40975  41384  40943  41165  41264  41157  42114  42928  42671
# 4  44635  46192  43507  42774  44166  43764  43379  43754  44388  45723
#
#     2017   2018
# 0    NaN    NaN
# 1     ..     ..
# 2  50578  49860
# 3  43025  42674
# ...

# %%
percapitaGDP = pd.read_excel("GDPpercapita.xlsx",
   sheet_name="OECD.Stat export",
   skiprows=5,
   skipfooter=1,
   usecols="A,D:T")
percapitaGDP.head()
# Out:
#            Metropolitan areas Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0              AUS: Australia         ..         ..         ..         ..
# 1       AUS01: Greater Sydney      44008      45424      45837      45423
# 2    AUS02: Greater Melbourne      40894      41602      42188      41484
# 3     AUS03: Greater Brisbane      37564      39080      40762      42976
# 4        AUS04: Greater Perth      47371      48719      51020      55278
#
#   Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12  \
# 0         ..         ..         ..          ..          ..          ..
# 1      45547      45880      45225       45900       45672       46535
# 2      41589      42316      40975       41384       40943       41165
# 3      44475      44635      46192       43507       42774       44166
# 4      60142      62551      63899       63616       70111       73715
#
#   Unnamed: 13 Unnamed: 14 Unnamed: 15 Unnamed: 16 Unnamed: 17 Unnamed: 18  \
# ...

# %%
print(percapitaGDP.sheet_names)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8292\2391092822.py in <module>
# ----> 1 print(percapitaGDP.sheet_names)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'sheet_names'

# %%
import pandas as pd

# Import the excel file and call it xls_file
excel_file = pd.ExcelFile('GDPpercapita.xlsx')

# View the excel_file's sheet names
print(excel_file.sheet_names)

# Load the excel_file's Sheet1 as a dataframe
df = excel_file.parse('OECD.Stat export')
# Out:
# ['Source', 'OECD.Stat export']

# %%
df.head()
# Out:
#                            NaN  \
# 0  Dataset: Metropolitan areas
# 1                    Variables
# 2                         Unit
# 3                         Year
# 4           Metropolitan areas
#
#    Sorry, the query is too large to fit into the Excel cell. You will not be able to update your table with the .Stat Populator.  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                           Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0                                                NaN        NaN        NaN
# 1  GDP per capita (USD, constant prices, constant...        NaN        NaN
# 2                                          US Dollar        NaN        NaN
# ...

# %%
import os
wd = os.getcwd()
os.listdir(wd)
# Out:
# ['.ipynb_checkpoints',
#  'chapter2.pdf',
#  'GDPpercapita.xlsx',
#  'gfg.xlsx',
#  'Introduction to other file types.ipynb']
