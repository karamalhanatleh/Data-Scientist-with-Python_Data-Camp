# %%
pip install Assembly
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.

# %%
import Assembly
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18436\300877329.py in <module>
# ----> 1 import Assembly
#
# ModuleNotFoundError: No module named 'Assembly'
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pandas 1.4.4 requires python-dateutil>=2.8.1, but you have python-dateutil 2.8.0 which is incompatible.
# jupyter-client 7.3.4 requires python-dateutil>=2.8.2, but you have python-dateutil 2.8.0 which is incompatible.
# conda-repo-cli 1.0.20 requires clyent==1.2.1, but you have clyent 1.2.2 which is incompatible.
# conda-repo-cli 1.0.20 requires nbformat==5.4.0, but you have nbformat 5.5.0 which is incompatible.
# ...
