# %%
# Importing course packages; you can add more too!
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Importing course datasets as DataFrames
climate_change = pd.read_csv('datasets/climate_change.csv', parse_dates=["date"], index_col="date")
medals = pd.read_csv('datasets/medals_by_country_2016.csv', index_col=0)
summer_2016 = pd.read_csv('datasets/summer2016.csv')
austin_weather = pd.read_csv("datasets/austin_weather.csv", index_col="DATE")
weather = pd.read_csv("datasets/seattle_weather.csv", index_col="DATE")
# Some pre-processing on the weather datasets, including adding a month column
seattle_weather = weather[weather["STATION"] == "USW00094290"] 
month = ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"] 
seattle_weather["MONTH"] = month 
austin_weather["MONTH"] = month
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_7036\3953587400.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   seattle_weather["MONTH"] = month

# %%
fig, ax = plt.subplots()
ax.bar(medals.index, medals["Gold"])
ax.set_xticklabels(medals.index, rotation=90)
ax.set_ylabel("Number of medals")
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_7036\1262621036.py:3: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(medals.index, rotation=90)

# %% [markdown]
# ## Saving the figure to file

# %%
fig, ax = plt.subplots()
ax.bar(medals.index, medals["Gold"])
ax.set_xticklabels(medals.index, rotation=90)
ax.set_ylabel("Number of medals")
fig.savefig("gold_medals.png")
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_7036\2957890795.py:3: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(medals.index, rotation=90)

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 7512-50B0
#
#  Directory of C:\Users\DELL\Desktop\python\datacamp\Introduction to Data Visualization with Matplotlib\Sharing visualizations with others
#
# 11/13/2022  07:53 PM    <DIR>          .
# 11/13/2022  07:53 PM    <DIR>          ..
# 11/13/2022  07:51 PM    <DIR>          .ipynb_checkpoints
# 11/13/2022  07:35 PM         1,663,347 chapter4.pdf
# 11/13/2022  07:38 PM    <DIR>          datasets
# 11/13/2022  07:53 PM            18,414 gold_medals.png
# 11/13/2022  07:51 PM           331,729 Preparing your figures to share with others.ipynb
# 11/13/2022  07:53 PM            31,996 Saving your visualizations.ipynb
#                4 File(s)      2,045,486 bytes
#                4 Dir(s)  136,146,157,568 bytes free

# %%
fig.savefig("gold_medals.jpg")

# %%
fig.savefig("gold_medals2.jpg" , quality=50)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_7036\2365319796.py:1: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "quality" which is no longer supported as of 3.3 and will become an error in 3.6
#   fig.savefig("gold_medals2.jpg" , quality=50)

# %%
fig.savefig("gold_medals.svg")

# %%
fig.savefig("gold_medals.png" , dpi=3000)

# %%
fig.savefig("gold_medals2.png" , dpi=30)
