# %% [markdown]
# # Outliers, leverage, and influence

# %%
# Import seaborn with alias sns
import seaborn as sns
# Import matplotlib.pyplot with alias plt
import matplotlib.pyplot as plt
#import pandas 
import pandas as pd
# import statsmodels
from statsmodels.formula.api import ols
#import numpy as np
import numpy as np

# %%
# Importing the course arrays
conversion = pd.read_csv("../datasets/ad_conversion.csv")
churn = pd.read_csv("../datasets/churn.csv")
fish = pd.read_csv("../datasets/fish.csv")
sp500 = pd.read_csv("../datasets/sp500_yearly_returns.csv")
taiwan = pd.read_csv("../datasets/taiwan_real_estate2.csv")
taiwan_real_estate= taiwan

# %%
roach = fish[fish['species'] == "Roach"]
print(roach.head())
# Out:
#    species  mass_g  length_cm
# 35   Roach    40.0       12.9
# 36   Roach    69.0       16.5
# 37   Roach    78.0       17.5
# 38   Roach    87.0       18.2
# 39   Roach   120.0       18.6

# %%
sns.regplot(x="length_cm",
            y="mass_g",
            data=roach,
            ci=None)
plt.show()

# %%
mdl_mass_vs_length = ols("mass_g ~ length_cm", data=bream).fit()
print(mdl_mass_vs_length.params)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10820\3879773780.py in <module>
# ----> 1 mdl_mass_vs_length = ols("mass_g ~ length_cm", data=bream).fit()
#       2 print(mdl_mass_vs_length.params)
#
# NameError: name 'bream' is not defined
